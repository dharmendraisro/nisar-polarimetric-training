# %% [markdown]
# # NISAR GCOV — Session and Troubleshooting

# %% [markdown]
# ## Geographic checkpoint
#
# Same as the other modules — spatial context stays attached throughout.

# %% [markdown]
# # 12 — Trainer Troubleshooting & Session Management
#
# Reference material for instructors: common session-state issues and a few performance-tuning notes. Not meant for participants to work through.

# %%
from pathlib import Path
from nisar_utils.bootstrap import setup_workshop
WORKSHOP_ROOT=setup_workshop()
from nisar_utils.config import load_config
from nisar_utils.workflow import build_profile

cfg=load_config()
profile=build_profile(cfg)
print("Session: OK")
print("File:",cfg["nisar_file"])
print("SAR family:",profile.sar_family)
print("Band:",profile.band)
print("Level:",profile.product_level)
print("Product:",profile.product_type)
print("Frequencies:",profile.frequencies)
print("Polarization:",profile.polarization_channels)

# %%
print("Troubleshooting:")
print("1. Run Module 01 after selecting/changing the NISAR file.")
print("2. Keep the same Python environment/kernel.")
print("3. Do not hard-code LSAR/SSAR, EPSG, frequency or polarization.")
print("4. ProductProfile is the source of truth.")
print("5. A single available frequency is selected automatically.")
print("6. AOI is optional; a training window is used when absent.")
print("7. Multiple frequencies require an explicit valid selection.")
print("\nModule 12 STATUS: PASS")
